# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.cross_validation import train_test_split
LE = LabelEncoder()

# %%
animal_data = pd.read_csv('csv_files/train.csv')
animal_data = animal_data.drop(labels=['AnimalID', 'Name', 'DateTime'], axis=1)

# %%
animal_data.head(20)
# Out:
#         OutcomeType OutcomeSubtype AnimalType SexuponOutcome AgeuponOutcome  \
# 0   Return_to_owner            NaN        Dog  Neutered Male         1 year
# 1        Euthanasia      Suffering        Cat  Spayed Female         1 year
# 2          Adoption         Foster        Dog  Neutered Male        2 years
# 3          Transfer        Partner        Cat    Intact Male        3 weeks
# 4          Transfer        Partner        Dog  Neutered Male        2 years
# 5          Transfer        Partner        Dog  Intact Female        1 month
# 6          Transfer        Partner        Cat    Intact Male        3 weeks
# 7          Transfer        Partner        Cat        Unknown        3 weeks
# 8          Adoption            NaN        Dog  Spayed Female       5 months
# 9          Adoption        Offsite        Dog  Spayed Female         1 year
# 10         Transfer           SCRP        Cat        Unknown        2 years
# 11         Adoption            NaN        Dog  Spayed Female        2 years
# 12         Adoption         Foster        Dog  Neutered Male        4 years
# 13  Return_to_owner            NaN        Dog  Neutered Male        2 years
# 14  Return_to_owner            NaN        Dog  Neutered Male         1 year
# 15         Adoption         Foster        Cat  Neutered Male       3 months
# 16         Transfer        Partner        Cat    Intact Male        3 weeks
# 17         Transfer        Partner        Dog  Intact Female        2 weeks
# 18         Transfer        Partner        Cat  Intact Female        2 years
# 19  Return_to_owner            NaN        Dog  Neutered Male         1 year
#
#                                 Breed               Color
# 0               Shetland Sheepdog Mix         Brown/White
# 1              Domestic Shorthair Mix         Cream Tabby
# 2                        Pit Bull Mix          Blue/White
# 3              Domestic Shorthair Mix          Blue Cream
# 4         Lhasa Apso/Miniature Poodle                 Tan
# 5   Cairn Terrier/Chihuahua Shorthair           Black/Tan
# 6              Domestic Shorthair Mix          Blue Tabby
# 7              Domestic Shorthair Mix         Brown Tabby
# 8       American Pit Bull Terrier Mix           Red/White
# 9                       Cairn Terrier               White
# 10             Domestic Shorthair Mix               Black
# 11            Miniature Schnauzer Mix              Silver
# 12                       Pit Bull Mix               Brown
# 13              Yorkshire Terrier Mix           Black/Red
# 14                 Great Pyrenees Mix         White/Cream
# 15             Domestic Shorthair Mix  Orange Tabby/White
# 16             Domestic Shorthair Mix         Brown Tabby
# 17                       Pit Bull Mix         Brown/White
# 18                         Angora Mix               White
# 19            Flat Coat Retriever Mix               Black

# %%
sample.head()
# Out:
#    ID  Adoption  Died  Euthanasia  Return_to_owner  Transfer
# 0   1         1     0           0                0         0
# 1   2         1     0           0                0         0
# 2   3         1     0           0                0         0
# 3   4         1     0           0                0         0
# 4   5         1     0           0                0         0
